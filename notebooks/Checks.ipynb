# %%
import sys
sys.path.insert(0, '/Users/matzhaugen/projects/pymaf/')
sys.path.insert(0, '/Users/matzhaugen/projects/pymaf/tests')

# %%
import numpy as np
from pymaf import maf, windowed_maf
from test_data import test_data
import matplotlib.pylab as plt

# %%
plt.plot(test_data)

# %%
f, w = maf(test_data)
plt.plot(f)

# %%
(np.sum(np.diff(f, axis=0), axis=0) > 0)
# Out:
# array([ True,  True,  True])

# %%
f, w = windowed_maf(test_data, 80, 3)
plt.plot(f)
# Out:
# [ True  True  True]
# [ True  True  True]
# [ True  True  True]
# [ True  True  True]
# [ True  True  True]
# [ True  True  True]
# [ True  True  True]
# [ True False  True]
# ...
